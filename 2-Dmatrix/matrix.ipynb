# %%
matrix = [
    [1, 2, 3],  # Row 0
    [4, 5, 6],  # Row 1
    [7, 8, 9]   # Row 2
]
#       Col0 Col1 Col2

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(matrix[0][0])  
print(matrix[1][2])  
print(matrix[2][1])
# Out:
# 1
# 6
# 8

# %%
num_rows = len(matrix)
num_cols = len(matrix[0])  

for i in range(num_rows): 
    for j in range(num_cols):  
        print(matrix[i][j], end=" ")  
    print()
# Out:
# 1 2 3
# 4 5 6
# 7 8 9

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

matrix[1][1] = 10  # Change the element at row 1, column 1 to 10

print(matrix)
# Out:
# [[1, 2, 3], [4, 10, 6], [7, 8, 9]]

# %%
def sum_matrix(matrix):
    total = 0
    for i in range(len(matrix)):
        for j in range(len(matrix[0])):
            total += matrix[i][j]
    return total

matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(sum_matrix(matrix))
# Out:
# 45

# %%
def transpose_matrix(matrix):
    num_rows = len(matrix)
    num_cols = len(matrix[0])

    
    transposed = [[0 for _ in range(num_rows)] for _ in range(num_cols)]

    for i in range(num_rows):
        for j in range(num_cols):
            transposed[j][i] = matrix[i][j] 

    return transposed

matrix = [
    [1, 2, 3],
    [4, 5, 6]
]

transposed_matrix = transpose_matrix(matrix)
print(transposed_matrix)
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
def zero_matrix(matrix):
    num_rows = len(matrix)
    num_cols = len(matrix[0])

    for i in range(num_rows):
        for j in range(num_cols):
            matrix[i][j] = 0
    return matrix

matrix = [
    [1, 2, 3],
    [4, 5, 6]
]

zero_matrix_result = zero_matrix(matrix)
print(zero_matrix_result)
# Out:
# [[0, 0, 0], [0, 0, 0]]
